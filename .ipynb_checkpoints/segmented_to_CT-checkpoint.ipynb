# %%
import vtk
from vtk.util import numpy_support
import os
import numpy
from matplotlib import pyplot, cm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for filename in os.listdir("data"):
    if filename.startswith("patient"): 
        print(os.path.join("data", filename))
        continue
    else:
        continue
# Out:
# data/patient11
# data/patient2
# data/patient19
# data/patient1
# data/patient4
# data/patient16
# data/patient13
# data/patient20
# data/patient18
# data/patient17
# data/patient10
# data/patient8
# data/patient5
# data/patient9
# data/patient12
# data/patient14
# data/patient3
# data/patient7
# data/patient15
# data/patient6

# %%
# This converts all the 3D DICOM images of all the patients to 3D numpy arrays
run to_arrays

# %%
# Each "ct"+str(i+1) is a 3D array of the 3D DICOM image of each patient's CT scan.

for i in range(20):
    locals()["ct"+str(i+1)] = patientCT[i]
    
# Each "seg" + str(i+1) is a 3D array of the segmented 3D DICOM liver image of the patient.     
    
for i in range(20):
    locals()["seg" + str(i+1)] = liver[i]

# %%
array = ct4

# %%
x = numpy.arange(0.0, (ConstPixelDims[0]+1)*ConstPixelSpacing[0], ConstPixelSpacing[0])
y = numpy.arange(0.0, (ConstPixelDims[1]+1)*ConstPixelSpacing[1], ConstPixelSpacing[1])
z = numpy.arange(0.0, (ConstPixelDims[2]+1)*ConstPixelSpacing[2], ConstPixelSpacing[2])

# %%
pyplot.figure(dpi=300)
pyplot.axes().set_aspect('equal', 'datalim')
pyplot.set_cmap(pyplot.gray())
pyplot.pcolormesh(x, y, numpy.flipud(numpy.rot90(array[:, :, 81])))
